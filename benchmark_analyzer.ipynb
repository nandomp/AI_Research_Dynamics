# %%
# !apt-get install -qq -y automake build-essential libtool
# !pip install pyjq
# Out:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 144865 files and directories currently installed.)
# Preparing to unpack .../0-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../1-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../2-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../3-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../4-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../5-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../6-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../7-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../8-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up autoconf (2.69-11) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libtool (2.4.6-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting pyjq
#   Downloading https://files.pythonhosted.org/packages/a5/7c/b7fdc7b9653d5f05552cb08b6e9883db13db21ca0c8b0cd100e5a5ed3a35/pyjq-2.4.0.tar.gz (2.0MB)
#      |████████████████████████████████| 2.0MB 4.2MB/s
# Building wheels for collected packages: pyjq
#   Building wheel for pyjq (setup.py) ... done
#   Created wheel for pyjq: filename=pyjq-2.4.0-cp36-cp36m-linux_x86_64.whl size=412329 sha256=dfb41766d4bad37c615724980412ac9ba273ed803b52daa6ff199692dbb67059
#   Stored in directory: /root/.cache/pip/wheels/13/b2/d3/db6be7dc71889f9bb7678ec2d9b2ce963a4038ffd1bc0c0748
# Successfully built pyjq
# Installing collected packages: pyjq
# Successfully installed pyjq-2.4.0

# %%
# activate R magic
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %%
# %%R
# install.packages(c("rPref","reticulate"), quiet=TRUE)
# Out:
# R[write to console]: also installing the dependencies ‘RcppParallel’, ‘igraph’, ‘rappdirs’

# %%
import json
import pyjq
import requests
import os
import gzip
import urllib.request
import collections
import numpy as np
import pandas as pd
import networkx as nx
from networkx.algorithms import community
import pathlib
from collections import Counter

# %%
# get arxiv id and removes version number
def get_arxiv_id(url):
    return url.split('/')[-1].split('v')[0]

# %%
def find_authors_scinapse(paper_title: str):
    title = paper_title.replace(" ", "+")
    authors = dict()
    response = requests.get(
        f"https://scinapse.io/api/search?q={title}&sort=RELEVANCE&filter=year%3D:,fos%3D,journal%3D&page=0&yd=true&wcm=c")
    if response.status_code == 200 and response.json()["data"]["content"]:
        for author in response.json()["data"]["content"][0]["authors"]:
            if author["affiliation"] is not None:
                authors[author["name"]] = author["affiliation"]["name"]
            else:
                authors[author["name"]] = ""

    return authors

# %%
def find_authors(paper_url, paper_title):
    authors = list()
    authors = find_authors_scinapse(paper_title)
    return authors

# %%
def scrap(task: str, dataset: str, metric_name: str):
    # Filter json to find only list of papers from imagenet
    evaluation = requests.get("https://paperswithcode.com/media/about/evaluation-tables.json.gz")
    #evaluation = urllib.request.urlopen("https://paperswithcode.com/media/about/evaluation-tables.json.gz")
    #data = json.load(evaluation.json())
    data = json.loads(gzip.decompress(evaluation.content))

    papers = list()
    affiliations = dict()

    json_net = pyjq.all(
        f".[] | select(.task=\"{task}\") | .datasets[] | select(.dataset==\"{dataset}\") | .sota.rows[]", data)
    for row in json_net:
        paper_title = row["paper_title"]
        paper_url = row["paper_url"]
        paper_date = row["paper_date"]
        metric = "not available"
        model_name = row["model_name"]

        try:
            metric = row["metrics"][metric_name]

        except KeyError:
            #print("no key found")
            metric = "not available"

        authors = find_authors(paper_url, paper_title)

        paper = {'title': f"{paper_title}@@@{model_name}", 'authors': [*authors.keys(
        )], 'affiliations': [*authors.values()], 'paper_date': paper_date, 'metric': metric}
        for author, affiliation in authors.items():
            affiliations[author] = affiliation

        papers.append(paper)
        # papers2.append(paper2)
    return papers, affiliations

# %%
def generate_unique_authors(papers: list):
    authors_dict = collections.defaultdict(dict)
    for paper in papers:
        for author in paper['authors']:
            for author2 in paper['authors']:
                if author not in authors_dict or author2 not in authors_dict[author]:
                    authors_dict[author][author2] = 0
                authors_dict[author][author2] += 1

    return authors_dict

# %%
def create_matrix(papers: list):
    authors = generate_unique_authors(papers)
    author_matrix = np.zeros([len(authors), len(authors)], dtype=int)
    i = 0
    for key in authors:
        j = 0
        for key2 in authors:
            if key2 in authors[key]:
                author_matrix[i][j] = authors[key][key2]
            j += 1
        i += 1
    df = pd.DataFrame(author_matrix, index=authors.keys(), columns=authors.keys())
    return df

# %%
def generate_communities(matrix: pd.DataFrame, affiliations: dict, papers: list):
    np.fill_diagonal(matrix.values, 0)
    print(matrix)
    adjacency_matrix = matrix.values

    graph_aux = nx.from_numpy_matrix(adjacency_matrix)

    mapping = dict(zip(graph_aux.nodes(), matrix.index))
    graph = nx.relabel_nodes(graph_aux, mapping)
    memberships = list(community.greedy_modularity_communities(graph))

    membership_names = collections.defaultdict(list)
    membership_names_complete = dict()
    membership_authors = dict()

    i = 0
    for membership_set in memberships:
        for author in membership_set:
            membership_names[str(i + 1)].append(affiliations[author])
            membership_authors[author] = str(i + 1)
        i = i + 1

    # Clean membership_names and create unique name
    for key, value in membership_names.items():
        membership_names[key] = list(filter(None, value))
        count = collections.Counter(membership_names[key])
        count = collections.Counter(count.most_common())
        affiliation_list = list()
        for k, v in count.items():
            affiliation_list.append(f"{k}")

        membership_names_complete[key] = "&".join(affiliation_list)

    paper_communities = {}
    activity = list()
    for paper in papers:
        paper_communities[paper['title']] = {'communities': set(), 'metric': str(), 'paper_date': str(),
                                             'communities_name': set()}

        for author in paper['authors']:
            paper_communities[paper['title']]['communities'].add(
                membership_authors[author])
            paper_communities[paper['title']]['communities_name'].update(membership_names[
                                                                             str(membership_authors[author])])
            paper_communities[paper['title']]['metric'] = paper['metric']
            paper_communities[paper['title']]['paper_date'] = paper['paper_date']
        paper_communities[paper['title']]['communities'] = "+".join(paper_communities[paper['title']]['communities'])

        for paper_community in paper_communities[paper['title']]['communities_name']:
            activity.append(paper_community)
    activity_counter = collections.Counter(activity)

    # exports
    df = pd.DataFrame.from_dict(paper_communities, orient="index")
    df2 = pd.DataFrame.from_dict(membership_names_complete, orient="index")
    df3 = pd.DataFrame.from_dict(dict(activity_counter), orient="index")
    df.index.names = ['title']
    df2.index.names = ['number']
    df2.columns = ['name']
    df3.index.names = ['institution']
    df3.columns = ['counter']
    df.to_csv('paper-communities.csv')
    df2.to_csv('legend-communities.csv')
    df3.to_csv('activity-communities.csv')
    with open("all-papers.json", "w") as outfile:
      json.dump(papers, outfile)

    print(df.head())
    print(df2.head())
    df.reset_index(level=0, inplace=True)
    df2.reset_index(level=0, inplace=True)
    df3.reset_index(level=0, inplace=True)
    return df, df2, df3

# %%
def generate_ranking(task: str, dataset: str, metric_name: str):
    papers, affiliations = scrap(task, dataset, metric_name)
    matrix = create_matrix(papers)
    return generate_communities(matrix, affiliations, papers)

# %%
benchmarks =[
   {
     "task":"Image Classification",
     "dataset":"STL-10",
     "metric_name":"Percentage correct" 
   },
#  {
#    "task":"Image Classification",
#    "dataset":"MNIST",
#    "metric_name":"Accuracy" 
#  },
   {
     "task":"Image Classification",
     "dataset":"ImageNet",
     "metric_name":"Top-1 Accuracy" 
   },
      {
     "task":"Image Classification",
     "dataset":"CIFAR-100",
     "metric_name":"Percentage correct" 
   },
     {
    "task":"Semantic Segmentation",
    "dataset":"Cityscapes test",
    "metric_name":"Mean IoU (class)" 
  },
    {
    "task":"Semantic Segmentation",
    "dataset":"PASCAL VOC 2012 test",
    "metric_name":"Mean IoU" 
  },
  {
    "task":"Object Detection",
    "dataset":"COCO test-dev",
    "metric_name":"box AP" 
  },
    {
    "task":"Object Detection",
    "dataset":"COCO minival",
    "metric_name":"box AP" 
  },
      {
    "task":"Object Detection",
    "dataset":"PASCAL VOC 2007",
    "metric_name":"MAP" 
  },
     {
    "task":"Image Generation",
    "dataset":"CIFAR-10",
    "metric_name":"FID" 
  },
  {
    "task":"Pose Estimation",
    "dataset":"MPII Human Pose",
    "metric_name":"PCKh-0.5" 
  },
   {
    "task":"Action Recognition",
    "dataset":"UCF101",
    "metric_name":"3-fold Accuracy" 
  },
     {
    "task":"Action Recognition",
    "dataset":"HMDB-51",
    "metric_name":"Average accuracy of 3 splits" 
  },
       {
    "task":"Image Super-Resolution",
    "dataset":"Set5 - 4x upscaling",
    "metric_name":"PSNR" 
  },
      {
    "task":"Machine Translation",
    "dataset":"WMT2014 English-German",
    "metric_name":"BLEU score" 
  },
       {
    "task":"Machine Translation",
    "dataset":"WMT2014 English-French",
    "metric_name":"BLEU score" 
  },
  {
    "task":"Question Answering",
    "dataset":"SQuAD1.1",
    "metric_name":"F1" 
  },
    {
    "task":"Question Answering",
    "dataset":"WikiQA",
    "metric_name":"MAP" 
  },
 # {
 #   "task":"Question Answering",
 #   "dataset":"SQuAD2.0",
 #   "metric_name":"F1" 
 # },
  {
    "task":"Language Modelling",
    "dataset":"WikiText-103",
    "metric_name":"Test perplexity" 
  },
 #  {
 #   "task":"Language Modelling",
 #   "dataset":"Penn Treebank (Word Level)",
 #   "metric_name":"Test perplexity" 
 #},
     {
    "task":"Language Modelling",
    "dataset":"enwik8",
    "metric_name":"Bit per Character (BPC)" 
  },

   {
    "task":"Sentiment Analysis",
    "dataset":"SST-2 Binary classification",
    "metric_name":"Accuracy" 
  },
 {
    "task":"Sentiment Analysis",
    "dataset":"IMDb",
    "metric_name":"Accuracy" 
  },
  {
    "task":"Named Entity Recognition",
    "dataset":"CoNLL 2003 (English)",
    "metric_name":"F1" 
  },
    {
    "task":"Named Entity Recognition",
    "dataset":"Ontonotes v5 (English)",
    "metric_name":"F1" 
  },
      {
    "task":"Natural Language Inference",
    "dataset":"SNLI",
    "metric_name":"% Test Accuracy" 
  },
      {
    "task":"Text Classification",
    "dataset":"AG News",
    "metric_name":"Error" 
  },
      {
    "task":"Speech Recognition",
    "dataset":"LibriSpeech test-clean",
    "metric_name":"Word Error Rate (WER)" 
  },
      {
    "task":"Node Classification",
    "dataset":"Pubmed",
    "metric_name":"Accuracy" 
  },
        {
    "task":"Node Classification",
    "dataset":"Citeseer",
    "metric_name":"Accuracy" 
  },
          {
    "task":"Link Prediction",
    "dataset":"WN18RR",
    "metric_name":"Hits@3" 
  },
          {
    "task":"Atari Games",
    "dataset":"Atari 2600 Montezuma's Revenge",
    "metric_name":"Score" 
  },
  {
    "task":"Atari Games",
    "dataset":"Atari 2600 Space Invaders",
    "metric_name":"Score" 
  }


]

# %%
all_papers = []
for benchmark in benchmarks:
  task=benchmark["task"]
  dataset=benchmark["dataset"]
  metric_name=benchmark["metric_name"]
  pathlib.Path(f"{task}/{dataset}").mkdir(parents=True, exist_ok=True)
  os.chdir(f"{task}/{dataset}")
  df1,df2,df3 = generate_ranking(task, dataset,metric_name)
  df1.communities_name=df1.communities_name.apply("@".join)
  all_papers.append(df1)
  
  os.chdir("../..")
# Out:
#                           Yuan Tian  ...  Amos J. Storkey
# Yuan Tian                         0  ...                0
# Qin Wang                          1  ...                0
# Zhiwu Huang                       1  ...                0
# Wen Li                            1  ...                0
# Dengxin Dai                       1  ...                0
# ...                             ...  ...              ...
# Jeff A. Bilmes                    0  ...                0
# Tanmoy Bhattacharya               0  ...                0
# Sarah E. Michalak                 0  ...                0
# Massimiliano Patacchiola          0  ...                1
# Amos J. Storkey                   0  ...                0
#
# [227 rows x 227 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Off-Policy Reinforcement Learning for Efficient...           3  ...                                                 {}
# DEGAS: Differentiable Efficient Generator Searc...          48  ...                              {Tel Aviv University}
# AutoGAN: Neural Architecture Search for Generat...          15  ...  {Huazhong University of Science and Technology...
# Dist-GAN: An Improved GAN using Distance Constr...          32  ...    {Singapore University of Technology and Design}
# Improving MMD-GAN Training with Repulsive Loss ...          33  ...  {RMIT University, Australian National Universi...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1                                           ('Google', 3)
# 2                           ('OpenAI', 7)&('Facebook', 1)
# 3
# 4       ('Peking University', 3)&('Chinese Academy of ...
# 5
#                         Cihang Xie  Yuxin Wu  ...  Pablo Samuel Castro  Erich Elsen
# Cihang Xie                       0         1  ...                    0            0
# Yuxin Wu                         1         0  ...                    0            0
# Laurens van der Maaten           1         1  ...                    0            0
# Alan L. Yuille                   6         1  ...                    0            0
# Kaiming He                       1         1  ...                    0            0
# ...                            ...       ...  ...                  ...          ...
# Utku Evci                        0         0  ...                    4            4
# Trevor Gale                      0         0  ...                    4            4
# Jacob Menick                     0         0  ...                    4            4
# Pablo Samuel Castro              0         0  ...                    0            4
# Erich Elsen                      0         0  ...                    4            0
#
# [504 rows x 504 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Feature Denoising for Improving Adversarial Rob...           2  ...  {Microsoft, Facebook, The Chinese University o...
# Neural Architecture Transfer@@@NAT-M4                        3  ...    {Massachusetts Institute of Technology, Google}
# NSGANetV2: Evolutionary Multi-Objective Surroga...          33  ...                        {Michigan State University}
# Neural Architecture Transfer@@@NAT-M3                        3  ...    {Massachusetts Institute of Technology, Google}
# NSGANetV2: Evolutionary Multi-Objective Surroga...          33  ...                        {Michigan State University}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 45)&('Courant Institute of Mathemat...
# 2       ('Facebook', 11)&('The Chinese University of H...
# 3       ('Google', 8)&('Massachusetts Institute of Tec...
# 4       ('Huawei', 4)&('Beihang University', 2)&('Shan...
# 5                                       ('Amazon.com', 6)
#                       Mingming Gong  Yanwu Xu  ...  Xuanyi Dong  Yi Yang
# Mingming Gong                     0         1  ...            0        0
# Yanwu Xu                          1         0  ...            0        0
# Chunyuan Li                       1         1  ...            0        0
# Kun Zhang                         1         1  ...            0        0
# Kayhan Batmanghelich              1         1  ...            0        0
# ...                             ...       ...  ...          ...      ...
# Dan Hendrycks                     0         0  ...            0        0
# Mantas Mazeika                    0         0  ...            0        0
# Thomas G. Dietterich              0         0  ...            0        0
# Xuanyi Dong                       0         0  ...            0        1
# Yi Yang                           0         0  ...            1        0
#
# [331 rows x 331 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Twin Auxilary Classifiers GAN@@@TAC-GAN                     19  ...  {University of Pittsburgh, University of Melbo...
# Self-supervised GAN: Analysis and Improvement w...          11  ...  {Singapore University of Technology and Design...
# Learnable Boundary Guided Adversarial Training@...          44  ...  {University of Technology, Sydney, University ...
# Learnable Boundary Guided Adversarial Training@...          44  ...  {University of Technology, Sydney, University ...
# Neural Architecture Transfer@@@NAT-M4                        4  ...    {Massachusetts Institute of Technology, Google}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1                                          ('Google', 25)
# 2       ('Université de Montréal', 7)&('Google', 5)&('...
# 3                                   ('Alibaba Group', 12)
# 4       ('Google', 8)&('Massachusetts Institute of Tec...
# 5       ('Intel', 3)&('Harvard University', 2)&('Unive...
#                     Lijun Wang  Jianming Zhang  ...  Luc Van Gool  Min Bai
# Lijun Wang                   0               1  ...             0        0
# Jianming Zhang               1               0  ...             0        0
# Oliver Wang                  1               1  ...             0        0
# Zhe Lin                      1               1  ...             0        0
# Huchuan Lu                   1               1  ...             0        0
# ...                        ...             ...  ...           ...      ...
# Davy Neven                   0               0  ...             3        0
# Bert De Brabandere           0               0  ...             3        0
# Marc Proesmans               0               0  ...             2        0
# Luc Van Gool                 0               0  ...             0        0
# Min Bai                      0               0  ...             0        0
#
# [262 rows x 262 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# SDC-Depth: Semantic Divide-and-Conquer Network ...          16  ...   {Dalian University of Technology, Adobe Systems}
# Variational Context-Deformable ConvNets for Ind...          23  ...            {Northwestern Polytechnical University}
# CASENet: Deep Category-Aware Semantic Edge Dete...          24  ...  {Mitsubishi Electric, Carnegie Mellon University}
# Hierarchical Multi-Scale Attention for Semantic...           3  ...         {University of California, Merced, Nvidia}
# Object-Contextual Representations for Semantic ...           5  ...  {Huazhong University of Science and Technology...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 17)&('University of Illinois at Urb...
# 2       ('University of Oxford', 6)&('Peking Universit...
# 3       ('Nvidia', 5)&('University of California, Merc...
# 4       ('The Chinese University of Hong Kong', 12)&('...
# 5       ('Huazhong University of Science and Technolog...
#                 Barret Zoph  Golnaz Ghiasi  ...  Xi Yin  Xiaoming Liu
# Barret Zoph               0              1  ...       0             0
# Golnaz Ghiasi             1              0  ...       0             0
# Tsung-Yi Lin              1              1  ...       0             0
# Yin Cui                   1              1  ...       0             0
# Hanxiao Liu               1              1  ...       0             0
# ...                     ...            ...  ...     ...           ...
# Zeynep Akata              0              0  ...       0             0
# Mario Fritz               0              0  ...       0             0
# Garrick Brazil            0              0  ...       1             1
# Xi Yin                    0              0  ...       0             1
# Xiaoming Liu              0              0  ...       1             0
#
# [149 rows x 149 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Rethinking Pre-training and Self-training@@@Eff...           1  ...  {University College London, Stanford Universit...
# Encoder-Decoder with Atrous Separable Convoluti...           1  ...  {University College London, Stanford Universit...
# Encoder-Decoder with Atrous Separable Convoluti...           1  ...  {University College London, Stanford Universit...
# Multi Receptive Field Network for Semantic Segm...           9  ...  {University of Electronic Science and Technolo...
# ExFuse: Enhancing Feature Fusion for Semantic S...           3  ...  {Peking University, Fudan University, Microsof...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 10)&('Johns Hopkins University', 2)...
# 2       ('Amazon.com', 6)&('The Chinese University of ...
# 3       ('Huazhong University of Science and Technolog...
# 4       ('Chinese Academy of Sciences', 4)&('Academy o...
# 5       ('University of Waterloo', 5)&('Xiamen Univers...
#               Feng Zhang  Xiatian Zhu  ...  Ping Luo  Xiangyang Ji
# Feng Zhang             0            1  ...         0             0
# Xiatian Zhu            1            0  ...         0             0
# Hanbin Dai             1            1  ...         0             0
# Mao Ye                 1            1  ...         0             0
# Ce Zhu                 1            1  ...         0             0
# ...                  ...          ...  ...       ...           ...
# Xiaoge Song            0            0  ...         2             0
# Xuebo Liu              0            0  ...         2             0
# Ding Liang             0            0  ...         2             0
# Ping Luo               0            0  ...         0             0
# Xiangyang Ji           0            0  ...         0             0
#
# [395 rows x 395 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Distribution-Aware Coordinate Representation fo...          18  ...  {Samsung, University of Electronic Science and...
# Deep High-Resolution Representation Learning fo...           4  ...  {Huazhong University of Science and Technology...
# EvoPose2D: Pushing the Boundaries of 2D Human P...          31  ...  {Imperial College London, Ulsan National Insti...
# The Devil is in the Details: Delving into Unbia...          23  ...                      {Chinese Academy of Sciences}
# Rethinking on Multi-Stage Networks for Human Po...           1  ...  {Peking University, Hong Kong University of Sc...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Microsoft', 12)&('The Chinese University of ...
# 2       ('Google', 24)&('Facebook', 4)&('Cornell Unive...
# 3       ('Tsinghua University', 3)&('University of Ade...
# 4       ('Huazhong University of Science and Technolog...
# 5       ('The Chinese University of Hong Kong', 8)&('U...
#                Wenbo Li  Zhicheng Wang  ...  Fanyi Xiao  Yong Jae Lee
# Wenbo Li              0              1  ...           0             0
# Zhicheng Wang         1              0  ...           0             0
# Binyi Yin             1              1  ...           0             0
# Qixiang Peng          1              1  ...           0             0
# Yuming Du             1              1  ...           0             0
# ...                 ...            ...  ...         ...           ...
# Haifang Qin           0              0  ...           0             0
# Daniel Bolya          0              0  ...           1             1
# Chong Zhou            0              0  ...           1             1
# Fanyi Xiao            0              0  ...           0             1
# Yong Jae Lee          0              0  ...           1             0
#
# [185 rows x 185 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Rethinking on Multi-Stage Networks for Human Po...           1  ...  {Peking University, Microsoft, Facebook, The C...
# Simple Copy-Paste is a Strong Data Augmentation...           8  ...                    {Shanghai Jiao Tong University}
# EfficientDet: Scalable and Efficient Object Det...           1  ...  {Peking University, Microsoft, Facebook, The C...
# Rethinking Pre-training and Self-training@@@Spi...           1  ...  {Peking University, Microsoft, Facebook, The C...
# ResNeSt: Split-Attention Networks@@@ResNeSt-200...           3  ...                           {University of Adelaide}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('The Chinese University of Hong Kong', 12)&('...
# 2       ('Huazhong University of Science and Technolog...
# 3                           ('University of Adelaide', 3)
# 4       ('Microsoft', 5)&('Peking University', 2)&('Ho...
# 5                              ('Tsinghua University', 2)
#                      Xiangtai Li  ...  Santosh K. Divvala
# Xiangtai Li                    0  ...                   0
# Li Zhang                       1  ...                   0
# Ansheng You                    1  ...                   0
# Maoke Yang                     1  ...                   0
# Kuiyuan Yang                   1  ...                   0
# ...                          ...  ...                 ...
# Sachin Mehta                   0  ...                   0
# Hannaneh Hajishirzi            0  ...                   0
# Mohammad Rastegari             0  ...                   0
# Linda G. Shapiro               0  ...                   0
# Santosh K. Divvala             0  ...                   0
#
# [151 rows x 151 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Global Aggregation then Local Distribution in F...           5  ...  {Peking University, University of Oxford, Micr...
# Revisiting Unreasonable Effectiveness of Data i...           1  ...  {Peking University, Allen Institute for Artifi...
# Co-localization with Category-Consistent Featur...          18  ...       {Stony Brook University, Harvard University}
# Asymmetric Loss For Multi-Label Classification@...           3  ...                                    {Alibaba Group}
# Learning Semantic-Specific Graph Representation...          13  ...  {Guangdong University of Foreign Studies, Sun ...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Carnegie Mellon University', 6)&('Microsoft'...
# 2            ('Massachusetts Institute of Technology', 8)
# 3                                    ('Alibaba Group', 1)
# 4       ('University of North Carolina at Chapel Hill'...
# 5       ('Peking University', 3)&('Microsoft', 1)&('Un...
#                       Antoine Liutkus  ...  Iain Murray
# Antoine Liutkus                     0  ...            0
# Umut Simsekli                       5  ...            0
# Szymon Majewski                     5  ...            0
# Alain Durmus                        5  ...            0
# Fabian-Robert Stöter                5  ...            0
# ...                               ...  ...          ...
# Jianmin Wang                        0  ...            0
# Jingdong Wang                       0  ...            0
# George Papamakarios                 0  ...            1
# Theo Pavlakou                       0  ...            1
# Iain Murray                         0  ...            0
#
# [622 rows x 622 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Score-Based Generative Modeling through Stochas...          33  ...                                {Télécom ParisTech}
# Score-Based Generative Modeling through Stochas...          33  ...                                {Télécom ParisTech}
# Score-Based Generative Modeling through Stochas...          33  ...                                {Télécom ParisTech}
# Training Generative Adversarial Networks with L...          24  ...                                           {Nvidia}
# Denoising Diffusion Probabilistic Models@@@Deno...           2  ...  {Facebook, Canadian Institute for Advanced Res...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Université de Montréal', 8)&('Carnegie Mello...
# 2       ('Google', 9)&('University of California, Berk...
# 3       ('Google', 14)&('Johannes Kepler University of...
# 4                                          ('Google', 20)
# 5       ('Shanghai Jiao Tong University', 4)&('Massach...
#                         Adrian Bulat  ...  Christoph Bregler
# Adrian Bulat                       0  ...                  0
# Jean Kossaifi                      2  ...                  0
# Georgios Tzimiropoulos             4  ...                  0
# Maja Pantic                        2  ...                  0
# Zhihui Su                          0  ...                  0
# ...                              ...  ...                ...
# Jonathan Tompson                   0  ...                  1
# Ross Goroshin                      0  ...                  1
# Arjun Jain                         0  ...                  1
# Yann LeCun                         0  ...                  1
# Christoph Bregler                  0  ...                  0
#
# [107 rows x 107 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Toward fast and accurate human pose estimation ...           9  ...  {Imperial College London, University of Nottin...
# Cascade Feature Aggregation for Human Pose Esti...           6  ...                                                 {}
# UniPose: Unified Human Pose Estimation in Singl...          21  ...                {Rochester Institute of Technology}
# Rethinking on Multi-Stage Networks for Human Po...           1  ...  {Peking University, Microsoft, University of S...
# Human Pose Estimation with Spatial Contextual I...           3  ...       {The Chinese University of Hong Kong, Baidu}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Microsoft', 4)&('University of Science and T...
# 2       ('Rutgers University', 3)&('IBM', 2)&('Bingham...
# 3       ('Baidu', 2)&('The Chinese University of Hong ...
# 4       ('The Chinese University of Hong Kong', 6)&('T...
# 5                               ('Max Planck Society', 7)
#                    M. Esat Kalfaoglu  ...  Jerome Revaud
# M. Esat Kalfaoglu                  0  ...              0
# Sinan Kalkan                       1  ...              0
# A. Aydin Alatan                    1  ...              0
# Haodong Duan                       0  ...              0
# Yue Zhao                           0  ...              0
# ...                              ...  ...            ...
# Yang Long                          0  ...              0
# Yu Guan                            0  ...              0
# Ling Shao                          0  ...              0
# Vasileios Choutas                  0  ...              1
# Jerome Revaud                      0  ...              0
#
# [132 rows x 132 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Late Temporal Modeling in 3D CNN Architectures ...          21  ...                 {Middle East Technical University}
# Omni-sourced Webly-supervised Learning for Vide...           2  ...                                                 {}
# Learning Spatio-Temporal Representation with Lo...           8  ...  {City University of Hong Kong, Microsoft, Univ...
# Quo Vadis, Action Recognition? A New Model and ...          13  ...  {Graz University of Technology, University of ...
# MARS: Motion-Augmented RGB Stream for Action Re...           3  ...  {École Normale Supérieure, French Institute fo...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Stanford University', 6)&('Google', 3)&('Uni...
# 2
# 3       ('École Normale Supérieure', 2)&('French Insti...
# 4                                       ('ETH Zurich', 1)
# 5       ('The Chinese University of Hong Kong', 3)&('T...
#                    M. Esat Kalfaoglu  Sinan Kalkan  ...  Yun-Hui Liu  Wei Liu
# M. Esat Kalfaoglu                  0             1  ...            0        0
# Sinan Kalkan                       1             0  ...            0        0
# A. Aydin Alatan                    1             1  ...            0        0
# Haodong Duan                       0             0  ...            0        0
# Yue Zhao                           0             0  ...            0        0
# ...                              ...           ...  ...          ...      ...
# Linchao Bao                        0             0  ...            1        1
# Shengfeng He                       0             0  ...            1        1
# Yunhui Liu                         0             0  ...            1        1
# Yun-Hui Liu                        0             0  ...            0        1
# Wei Liu                            0             0  ...            1        0
#
# [103 rows x 103 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Late Temporal Modeling in 3D CNN Architectures ...          16  ...                 {Middle East Technical University}
# Omni-sourced Webly-supervised Learning for Vide...           7  ...                                                 {}
# @@@BubbleNET                                                    ...                                                 {}
# Hallucinating IDT Descriptors and I3D Optical F...          17  ...  {Commonwealth Scientific and Industrial Resear...
# Cooperative Cross-Stream Network for Discrimina...          12  ...  {University of Electronic Science and Technolo...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Facebook', 5)&('Carnegie Mellon University',...
# 2                                       ('ETH Zurich', 1)
# 3       ('Carnegie Mellon University', 2)&('University...
# 4       ('The Chinese University of Hong Kong', 3)&('T...
# 5       ('École Normale Supérieure', 2)&('French Insti...
#                      Yulun Zhang  Kunpeng Li  ...  Alexandre Alahi  Li Fei-Fei
# Yulun Zhang                    0           2  ...                0           0
# Kunpeng Li                     2           0  ...                0           0
# Kai Li                         2           2  ...                0           0
# Lichen Wang                    2           2  ...                0           0
# Bineng Zhong                   3           2  ...                0           0
# ...                          ...         ...  ...              ...         ...
# Harrish Thasarathan            0           0  ...                0           0
# Mehran Ebrahimi                0           0  ...                0           0
# Justin Johnson                 0           0  ...                1           1
# Alexandre Alahi                0           0  ...                0           1
# Li Fei-Fei                     0           0  ...                1           0
#
# [194 rows x 194 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Image Super-Resolution Using Very Deep Residual...           7  ...  {University of Rochester, Huaqiao University, ...
# Learned Image Downscaling for Upscaling using C...          33  ...                                 {Wuhan University}
# Single Image Super-Resolution via a Holistic At...           5  ...                                                 {}
# Image Reconstruction with Predictive Filter Flo...          34  ...                                                 {}
# Densely Residual Laplacian Super-Resolution@@@D...          35  ...                                                 {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Harbin Institute of Technology', 4)&('Tsingh...
# 2       ('University of Illinois at Urbana–Champaign',...
# 3          ('Twitter', 11)&('Imperial College London', 1)
# 4       ('The Chinese University of Hong Kong', 5)&('C...
# 5
#                 Sergey Edunov  Myle Ott  ...  Shufang Xie  Xiang-Yang Li
# Sergey Edunov               0         2  ...            0              0
# Myle Ott                    2         0  ...            0              0
# Michael Auli                2         2  ...            0              0
# David Grangier              2         2  ...            0              0
# Colin Raffel                0         0  ...            0              0
# ...                       ...       ...  ...          ...            ...
# Gorka Labaka                0         0  ...            0              0
# Eneko Agirre                0         0  ...            0              0
# Yang Fan                    0         0  ...            1              1
# Shufang Xie                 0         0  ...            0              1
# Xiang-Yang Li               0         0  ...            1              0
#
# [168 rows x 168 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Understanding Back-Translation at Scale@@@Noisy...           3  ...  {Harvard University, Facebook, Cornell Univers...
# Exploring the Limits of Transfer Learning with ...         1+5  ...  {University of Amsterdam, University of Southe...
# Incorporating BERT into Neural Machine Translat...           2  ...  {Peking University, University of Illinois at ...
# Data Diversification: A Simple Strategy For Neu...          12  ...                                                 {}
# Very Deep Transformers for Neural Machine Trans...          13  ...  {Johns Hopkins University, University of Illin...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 21)&('University of Southern Califo...
# 2       ('Microsoft', 8)&('University of Science and T...
# 3       ('Facebook', 11)&('Cornell University', 1)&('H...
# 4       ('Carnegie Mellon University', 7)&('Tencent', ...
# 5
#                       Xiaodong Liu  Kevin Duh  ...  Gorka Labaka  Eneko Agirre
# Xiaodong Liu                     0          2  ...             0             0
# Kevin Duh                        2          0  ...             0             0
# Liyuan Liu                       2          2  ...             0             0
# Jianfeng Gao                     2          2  ...             0             0
# Sergey Edunov                    0          0  ...             0             0
# ...                            ...        ...  ...           ...           ...
# Marc'Aurelio Ranzato             0          0  ...             0             0
# Samy Bengio                      0          0  ...             0             0
# Mikel Artetxe                    0          0  ...             1             1
# Gorka Labaka                     0          0  ...             0             1
# Eneko Agirre                     0          0  ...             1             0
#
# [120 rows x 120 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Very Deep Transformers for Neural Machine Trans...          11  ...  {Johns Hopkins University, University of Illin...
# Understanding Back-Translation at Scale@@@Noisy...           2  ...  {Harvard University, Facebook, Cornell Univers...
# Pre-training Multilingual Neural Machine Transl...           4  ...                                 {Fudan University}
# Very Deep Transformers for Neural Machine Trans...          11  ...  {Johns Hopkins University, University of Illin...
# MUSE: Parallel Multi-Scale Attention for Sequen...           9  ...                                                 {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 14)&('University of Southern Califo...
# 2       ('Facebook', 11)&('Cornell University', 1)&('H...
# 3       ('Google', 6)&('Jagiellonian University', 1)&(...
# 4                                 ('Fudan University', 3)
# 5
#                   Ikuya Yamada  Akari Asai  ...  Qingyu Zhou  Chuanqi Tan
# Ikuya Yamada                 0           1  ...            0            0
# Akari Asai                   1           0  ...            0            0
# Hiroyuki Shindo              1           1  ...            0            0
# Hideaki Takeda               1           1  ...            0            0
# Yuji Matsumoto               1           1  ...            0            0
# ...                        ...         ...  ...          ...          ...
# Daniel Gildea                0           0  ...            0            0
# Tom Hosking                  0           0  ...            0            0
# Sebastian Riedel             0           0  ...            0            0
# Qingyu Zhou                  0           0  ...            0            1
# Chuanqi Tan                  0           0  ...            1            0
#
# [163 rows x 163 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# LUKE: Deep Contextualized Entity Representation...          11  ...  {National Institute of Informatics, Nara Insti...
# @@@XLNet (single model)                                         ...                                                 {}
# XLNet: Generalized Autoregressive Pretraining f...           3  ...  {Beihang University, Google, Carnegie Mellon U...
# @@@XLNET-123++ (single model)                                   ...                                                 {}
# @@@XLNET-123+ (single model)                                    ...                                                 {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Microsoft', 14)&('National University of Def...
# 2       ('Google', 6)&('University of Washington', 5)&...
# 3       ('Carnegie Mellon University', 12)&('Google', ...
# 4
# 5
#                        Siddhant Garg  Thuy Vu  ...  Quoc V. Le  Tomas Mikolov
# Siddhant Garg                      0        1  ...           0              0
# Thuy Vu                            1        0  ...           0              0
# Alessandro Moschitti               1        1  ...           0              0
# Seunghyun Yoon                     0        0  ...           0              0
# Franck Dernoncourt                 0        0  ...           0              0
# Doo Soon Kim                       0        0  ...           0              0
# Trung Bui                          0        0  ...           0              0
# Kyomin Jung                        0        0  ...           0              0
# Runqi Yang                         0        0  ...           0              0
# Jianhai Zhang                      0        0  ...           0              0
# Xing Gao                           0        0  ...           0              0
# Feng Ji                            0        0  ...           0              0
# Haiqing Chen                       0        0  ...           0              0
# Yi Tay                             0        0  ...           0              0
# Luu Anh Tuan                       0        0  ...           0              0
# Siu Cheung Hui                     0        0  ...           0              0
# Hua He                             0        0  ...           0              0
# James Jeng-Weei Lin                0        0  ...           0              0
# Jimmy Lin                          0        0  ...           0              0
# Alexander H. Miller                0        0  ...           0              0
# Adam Fisch                         0        0  ...           0              0
# Jesse Dodge                        0        0  ...           0              0
# Amir-Hossein Karimi                0        0  ...           0              0
# Antoine Bordes                     0        0  ...           0              0
# Jason Weston                       0        0  ...           0              0
# Zhiguo Wang                        0        0  ...           0              0
# Haitao Mi                          0        0  ...           0              0
# Abraham Ittycheriah                0        0  ...           0              0
# Zhuang Ma                          0        0  ...           0              0
# Michael Collins                    0        0  ...           0              0
# Yishu Miao                         0        0  ...           0              0
# Lei Yu                             0        0  ...           0              0
# Phil Blunsom                       0        0  ...           0              0
# Shuangjie Xu                       0        0  ...           0              0
# Yu Cheng                           0        0  ...           0              0
# Kang Gu                            0        0  ...           0              0
# Yang Yang                          0        0  ...           0              0
# Shiyu Chang                        0        0  ...           0              0
# Pan Zhou                           0        0  ...           0              0
# Tsendsuren Munkhdalai              0        0  ...           0              0
# Hong Yu                            0        0  ...           0              0
# Dinghan Shen                       0        0  ...           0              0
# Guoyin Wang                        0        0  ...           0              0
# Wenlin Wang                        0        0  ...           0              0
# Martin Renqiang Min                0        0  ...           0              0
# Qinliang Su                        0        0  ...           0              0
# Zhang Yizhe                        0        0  ...           0              0
# Yizhe Zhang                        0        0  ...           0              0
# Chunyuan Li                        0        0  ...           0              0
# Ricardo Henao                      0        0  ...           0              0
# Lawrence Carin                     0        0  ...           0              0
# Karl Moritz Hermann                0        0  ...           0              0
# Stephen Pulman                     0        0  ...           0              0
# Quoc V. Le                         0        0  ...           0              2
# Tomas Mikolov                      0        0  ...           2              0
#
# [55 rows x 55 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# TANDA: Transfer and Adapt Pre-Trained Transform...           7  ...      {Amazon.com, University of Wisconsin-Madison}
# A Compare-Aggregate Model with Latent Clusterin...           4  ...         {Seoul National University, Adobe Systems}
# Simple and Effective Text Matching with Richer ...           5  ...                                    {Alibaba Group}
# Hyperbolic Representation Learning for Fast and...           8  ...  {Nanyang Technological University, Institute f...
# Pairwise Word Interaction Modeling with Deep Ne...           9  ...  {University of Maryland, College Park, Univers...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Duke University', 7)&('University of Notre D...
# 2       ('Facebook', 4)&('Carnegie Mellon University',...
# 3       ('Huazhong University of Science and Technolog...
# 4       ('Adobe Systems', 3)&('Seoul National Universi...
# 5                                    ('Alibaba Group', 2)
#                          Mohammad Shoeybi  ...  Sumeet Agarwal
# Mohammad Shoeybi                        0  ...               0
# Mostofa Patwary                         1  ...               0
# Md. Mostofa Ali Patwary                 1  ...               0
# Raul Puri                               1  ...               0
# Patrick LeGresley                       1  ...               0
# ...                                   ...  ...             ...
# Denis Yarats                            0  ...               0
# Gantavya Bhatt                          0  ...               3
# Hritik Bansal                           0  ...               3
# Rishubh Singh                           0  ...               3
# Sumeet Agarwal                          0  ...               0
#
# [91 rows x 91 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Megatron-LM: Training Multi-Billion Parameter L...           4  ...                                           {Nvidia}
# Generalization through Memorization: Nearest Ne...           3  ...  {Allen Institute for Artificial Intelligence, ...
# Efficient Content-Based Sparse Attention with R...           1  ...                                 {Facebook, Google}
# Dynamic Evaluation of Transformer Language Mode...           8  ...                          {University of Edinburgh}
# Dynamic Evaluation of Transformer Language Mode...           8  ...                          {University of Edinburgh}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1                          ('Facebook', 10)&('Google', 1)
# 2          ('Google', 3)&('University College London', 1)
# 3       ('University of Washington', 5)&('Facebook', 4...
# 4                                           ('Nvidia', 1)
# 5         ('Carnegie Mellon University', 5)&('Google', 1)
#                        Michael Wick  Kate Silverstein  ...  David Ha  Andrew M. Dai
# Michael Wick                      0                 1  ...         0              0
# Kate Silverstein                  1                 0  ...         0              0
# Jean-Baptiste Tristan             1                 1  ...         0              0
# Adam Craig Pocock                 1                 1  ...         0              0
# Mark Johnson                      1                 1  ...         0              0
# ...                             ...               ...  ...       ...            ...
# Junyoung Chung                    0                 0  ...         0              0
# Sungjin Ahn                       0                 0  ...         0              0
# Yoshua Bengio                     0                 0  ...         0              0
# David Ha                          0                 0  ...         0              1
# Andrew M. Dai                     0                 0  ...         1              0
#
# [87 rows x 87 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Language Models are Unsupervised Multitask Lear...           5  ...               {Boston College, Oracle Corporation}
# Dynamic Evaluation of Transformer Language Mode...           9  ...                          {University of Edinburgh}
# Accessing Higher-level Representations in Seque...           1  ...                                         {Facebook}
# Improving Transformer Models by Reordering thei...          14  ...  {Allen Institute for Artificial Intelligence, ...
# Compressive Transformers for Long-Range Sequenc...          11  ...                                                 {}
#
# [5 rows x 4 columns]
#                                                    name
# number
# 1                                       ('Facebook', 7)
# 2                                      ('Microsoft', 8)
# 3       ('Carnegie Mellon University', 4)&('Google', 4)
# 4                          ('University of Toronto', 1)
# 5       ('Oracle Corporation', 4)&('Boston College', 1)
#                    Colin Raffel  Noam Shazeer  ...  Giuseppe Carenini  Raymond T. Ng
# Colin Raffel                  0             5  ...                  0              0
# Noam Shazeer                  5             0  ...                  0              0
# Adam Roberts                  5             5  ...                  0              0
# Katherine Lee                 5             5  ...                  0              0
# Sharan Narang                 5             5  ...                  0              0
# ...                         ...           ...  ...                ...            ...
# Yuxin Tian                    0             0  ...                  0              0
# Luyang Liu                    0             0  ...                  0              0
# Bita Nejat                    0             0  ...                  1              1
# Giuseppe Carenini             0             0  ...                  0              1
# Raymond T. Ng                 0             0  ...                  1              0
#
# [201 rows x 201 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Exploring the Limits of Transfer Learning with ...           7  ...                                                 {}
# ALBERT: A Lite BERT for Self-supervised Learnin...          10  ...  {New York University, Toyota Technological Ins...
# Exploring the Limits of Transfer Learning with ...           7  ...                                                 {}
# XLNet: Generalized Autoregressive Pretraining f...          11  ...               {Google, Carnegie Mellon University}
# @@@ELECTRA                                                      ...                                                 {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Salesforce.com', 10)&('Stanford University',...
# 2                              ('Tsinghua University', 3)
# 3       ('Facebook', 6)&('University of Washington', 2...
# 4                                           ('Google', 7)
# 5
#                      Guoji Fu  Bo Yuan  ...  Jimmy Lin  James Jeng-Weei Lin
# Guoji Fu                    0        1  ...          0                    0
# Bo Yuan                     1        0  ...          0                    0
# Qiqi Duan                   1        1  ...          0                    0
# Xin Yao                     1        1  ...          0                    0
# Tan Thongtan                0        0  ...          0                    0
# ...                       ...      ...  ...        ...                  ...
# Ashutosh Adhikari           0        0  ...          1                    1
# Achyudh Ram                 0        0  ...          1                    1
# Raphael Tang                0        0  ...          1                    1
# Jimmy Lin                   0        0  ...          0                    1
# James Jeng-Weei Lin         0        0  ...          1                    0
#
# [117 rows x 117 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Representation Learning for Heterogeneous Infor...          10  ...    {Southern University of Science and Technology}
# Sentiment Classification Using Document Embeddi...          19  ...  {Mahidol University International College, Mah...
# Graph Star Net for Generalized Multi-Task Learn...          11  ...                                           {Huawei}
# Unsupervised Data Augmentation for Consistency ...           3  ...               {Google, Carnegie Mellon University}
# Revisiting LSTM Networks for Semi-Supervised Te...           3  ...               {Google, Carnegie Mellon University}
#
# ...
# title                                                           ...
# Self-Explaining Structures Improve NLP Models@@...          21  ...                       {National Taiwan University}
# Conditionally Adaptive Multi-Task Learning: Imp...          22  ...                  {École Polytechnique de Montréal}
# Semantics-aware BERT for Language Understanding...           7  ...                    {Shanghai Jiao Tong University}
# Multi-Task Deep Neural Networks for Natural Lan...           1  ...  {Peking University, Microsoft, Beihang Univers...
# Explicit Contextual Semantics for Text Comprehe...           7  ...                    {Shanghai Jiao Tong University}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Microsoft', 10)&('University of Edinburgh', ...
# 2
# 3       ('Stanford University', 9)&('Salesforce.com', ...
# 4       ('Philips', 7)&('Oregon State University', 1)&...
# 5       ('Duke University', 7)&('University of Notre D...
#                       Zhilin Yang  Zihang Dai  ...  Yuxin Tian  Luyang Liu
# Zhilin Yang                     0           1  ...           0           0
# Zihang Dai                      1           0  ...           0           0
# Yiming Yang                     1           1  ...           0           0
# Jaime G. Carbonell              1           1  ...           0           0
# Ruslan Salakhutdinov            1           1  ...           0           0
# ...                           ...         ...  ...         ...         ...
# Heyan Huang                     0           0  ...           1           1
# Yang Gao                        0           0  ...           1           1
# Xiaochi Wei                     0           0  ...           1           1
# Yuxin Tian                      0           0  ...           0           1
# Luyang Liu                      0           0  ...           1           0
#
# [78 rows x 78 columns]
#                                                    communities  ...                          communities_name
# title                                                           ...
# XLNet: Generalized Autoregressive Pretraining f...           2  ...      {Google, Carnegie Mellon University}
# How to Fine-Tune BERT for Text Classification?@...           8  ...                        {Fudan University}
# Revisiting LSTM Networks for Semi-Supervised Te...           2  ...      {Google, Carnegie Mellon University}
# Universal Language Model Fine-tuning for Text C...          13  ...  {National University of Ireland, Galway}
# Disconnected Recurrent Neural Networks for Text...          17  ...                                        {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Duke University', 10)&('Princeton University...
# 2         ('Carnegie Mellon University', 6)&('Google', 1)
# 3       ('Nanjing University of Posts and Telecommunic...
# 4       ('Courant Institute of Mathematical Sciences',...
# 5       ('Shandong University', 4)&('National Universi...
#                   Yu Zhang  James Qin  ...  Wei-Ning Hsu  Ann Lee
# Yu Zhang                 0          4  ...             0        0
# James Qin                4          0  ...             0        0
# Daniel S. Park           4          1  ...             0        0
# Wei Han                  5          4  ...             0        0
# Chung-Cheng Chiu         7          4  ...             0        0
# ...                    ...        ...  ...           ...      ...
# Thibaut Lavril           0          0  ...             0        0
# Maël Primet              0          0  ...             0        0
# Joseph Dureau            0          0  ...             0        0
# Wei-Ning Hsu             0          0  ...             0        1
# Ann Lee                  0          0  ...             1        0
#
# [139 rows x 139 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Pushing the Limits of Semi-Supervised Learning ...           2  ...                                           {Google}
# Improved Noisy Student Training for Automatic S...           2  ...                                           {Google}
# ASAPP-ASR: Multistream CNN and Self-Attentive S...           9  ...                                                 {}
# wav2vec 2.0: A Framework for Self-Supervised Le...           1  ...  {Nara Institute of Science and Technology, Fac...
# ContextNet: Improving Convolutional Neural Netw...           2  ...                                           {Google}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Facebook', 12)&('Nara Institute of Science a...
# 2                                           ('Google', 8)
# 3       ('Johns Hopkins University', 5)&('Tencent', 1)...
# 4                                         ('Facebook', 7)
# 5
#                Shirui Pan  Ruiqi Hu  ...  Samy Bengio  Cho-Jui Hsieh
# Shirui Pan              0         1  ...            0              0
# Ruiqi Hu                1         0  ...            0              0
# Guodong Long            2         1  ...            0              0
# Jing Jiang              2         1  ...            0              0
# Lina Yao                1         1  ...            0              0
# ...                   ...       ...  ...          ...            ...
# Xuanqing Liu            0         0  ...            1              1
# Si Si                   0         0  ...            1              1
# Yang Li                 0         0  ...            1              1
# Samy Bengio             0         0  ...            0              1
# Cho-Jui Hsieh           0         0  ...            1              0
#
# [227 rows x 227 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Adversarially Regularized Graph Autoencoder for...           4  ...  {University of New South Wales, University of ...
# Hyperspherical Variational Auto-Encoders@@@S-VGAE           14  ...                          {University of Amsterdam}
# Mutual Information Maximization in Graph Neural...          23  ...                                                 {}
# Rethinking Kernel Methods for Node Representati...          24  ...       {University of Delaware, Rutgers University}
# Graph InfoClust: Leveraging cluster-level node ...          42  ...                                                 {}
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1
# 2       ('University of Cambridge', 2)&('Université de...
# 3       ('Duke University', 8)&('Facebook', 1)&('Micro...
# 4       ('University of Technology, Sydney', 6)&('Flor...
# 5       ('ECRI Institute', 4)&('University of Oxford',...
#                     Costas Mavromatis  George Karypis  ...  Chuan Chen  Zibin Zheng
# Costas Mavromatis                   0               2  ...           0            0
# George Karypis                      2               0  ...           0            0
# Hong Yang                           0               0  ...           0            0
# Shirui Pan                          0               0  ...           0            0
# Peng Zhang                          0               0  ...           0            0
# ...                               ...             ...  ...         ...          ...
# Rami Al-Rfou                        0               0  ...           0            0
# Alexander A. Alemi                  0               0  ...           0            0
# Fanghua Ye                          0               0  ...           1            1
# Chuan Chen                          0               0  ...           0            1
# Zibin Zheng                         0               0  ...           1            0
#
# [171 rows x 171 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Graph InfoClust: Leveraging cluster-level node ...          33  ...                                                 {}
# Binarized Attributed Network Embedding@@@BANE                1  ...  {University of New South Wales, University of ...
# Hyperspherical Variational Auto-Encoders@@@S-VGAE            7  ...                          {University of Amsterdam}
# Mutual Information Maximization in Graph Neural...          14  ...                                                 {}
# Adversarially Regularized Graph Autoencoder for...           1  ...  {University of New South Wales, University of ...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('University of Technology, Sydney', 7)&('Flor...
# 2       ('University of Cambridge', 2)&('Université de...
# 3       ('Google', 5)&('University of Southern Califor...
# 4       ('Duke University', 8)&('Facebook', 1)&('Micro...
# 5       ('Texas A&M University', 5)&('University of Te...
#                 Wen Zhang  Bibek Paudel  ...  Farnood Salehi  Stephan Mandt
# Wen Zhang               0             1  ...               0              0
# Bibek Paudel            1             0  ...               0              0
# Liang Wang              1             1  ...               0              0
# Jiaoyan Chen            1             1  ...               0              0
# Hai Zhu                 1             1  ...               0              0
# ...                   ...           ...  ...             ...            ...
# Wen-tau Yih             0             0  ...               0              0
# Li Deng                 0             0  ...               0              0
# Robert Bamler           0             0  ...               1              1
# Farnood Salehi          0             0  ...               0              1
# Stephan Mandt           0             0  ...               1              0
#
# [122 rows x 122 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Theoretical Knowledge Graph Reasoning via Endin...           2  ...  {University of Zurich, Alibaba Group, Universi...
# MLMLM: Link Prediction with Mean Likelihood Mas...           8  ...                                                 {}
# Knowledge Graph Embedding via Graph Attenuated ...           9  ...                               {Huaqiao University}
# Predicting Semantic Relations using Global Grap...          22  ...                  {Georgia Institute of Technology}
# Low-Dimensional Hyperbolic Knowledge Graph Embe...           3  ...  {University of Massachusetts Amherst, Stanford...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Microsoft', 8)&('University of Connecticut',...
# 2       ('Zhejiang University', 3)&('University of Zur...
# 3       ('Stanford University', 4)&('Google', 2)&('Uni...
# 4       ('University College London', 4)&('Xerox', 1)&...
# 5       ('Centre national de la recherche scientifique...
#                       Adrien Ecoffet  ...  Mark Rowland
# Adrien Ecoffet                     0  ...             0
# Joost Huizinga                     2  ...             0
# Joel Lehman                        2  ...             0
# Kenneth O. Stanley                 2  ...             0
# Jeff Clune                         2  ...             0
# ...                              ...  ...           ...
# Sylvain Cussat-Blanc               0  ...             0
# Hervé Luga                         0  ...             0
# Julian F. Miller                   0  ...             0
# Xiangxiang Chu                     0  ...             0
# Mark Rowland                       0  ...             0
#
# [116 rows x 116 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# First return then explore@@@Go-Explore                       7  ...                                                 {}
# Go-Explore: a New Approach for Hard-Exploration...           7  ...                                                 {}
# Agent57: Outperforming the Atari Human Benchmar...           2  ...  {Stanford University, Université de Montréal, ...
# Exploration by Random Network Distillation@@@RND             4  ...  {University of Edinburgh, University of Califo...
# Contingency-Aware Exploration in Reinforcement ...         6+1  ...  {University of Alberta, University of Cambridg...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 18)&('University of Alberta', 2)&('...
# 2       ('Google', 8)&('Université de Montréal', 1)&('...
# 3                                           ('Google', 1)
# 4       ('University of Edinburgh', 3)&('University of...
# 5       ('Microsoft', 4)&('University of California, S...
#                       Julian Schrittwieser  ...  Joseph Modayil
# Julian Schrittwieser                     0  ...               0
# Ioannis Antonoglou                       1  ...               0
# Thomas Hubert                            1  ...               0
# Karen Simonyan                           1  ...               0
# Laurent Sifre                            1  ...               0
# ...                                    ...  ...             ...
# Mikhail Pavlov                           0  ...               0
# Aleksandr Fedorov                        0  ...               0
# Anastasiia Ignateva                      0  ...               0
# Petros Christodoulou                     0  ...               0
# Joseph Modayil                           0  ...               0
#
# [119 rows x 119 columns]
#                                                    communities  ...                                   communities_name
# title                                                           ...
# Mastering Atari, Go, Chess and Shogi by Plannin...           1  ...  {Stanford University, Northwestern University,...
# Distributed Prioritized Experience Replay@@@Ape-X          1+2  ...  {University of Alberta, Stanford University, U...
# Agent57: Outperforming the Atari Human Benchmar...           1  ...  {Stanford University, Northwestern University,...
# Fully Parameterized Quantile Function for Distr...           5  ...  {Tsinghua University, Microsoft, University of...
# IMPALA: Scalable Distributed Deep-RL with Impor...           1  ...  {Stanford University, Northwestern University,...
#
# [5 rows x 4 columns]
#                                                      name
# number
# 1       ('Google', 9)&('Stanford University', 2)&('Uni...
# 2       ('Google', 13)&('University of Alberta', 4)&('...
# 3                                           ('Google', 1)
# 4       ('Microsoft', 4)&('University of California, S...
# 5       ('Microsoft', 4)&('University of California, S...

# %%
# %%R -i all_papers
# #install.packages(c("rPref","reticulate"), quiet=TRUE)
# library(dplyr)
# library("rPref")
# library(ggplot2)
# #library(ggrepel)
# #library(xtable)
# #library(kableExtra)
# library(magrittr)
# library(reticulate)
# use_python("/usr/local/bin/python")
# #library(reticulate)
#
# cleanData <- function(ranking){
#   ranking_clean <- ranking[ranking$communities !="", ]
#   ranking_clean <- ranking_clean[ranking_clean$metric !="not available", ]
#
#   ranking_clean <- ranking_clean[which(!sapply(ranking_clean$paper_date, is.null)), ]
#   ranking_clean$paper_date <- array(as.character(unlist(ranking_clean$paper_date)))
#   ranking_clean$paper_date <- as.Date(ranking_clean$paper_date, "%Y-%m-%d")
#   ranking_clean$metric <- as.numeric(sub("%", "",ranking_clean$metric))
#
#   return(ranking_clean)
# }
#
#
# calculatePareto <- function(ranking_clean, is_positive=TRUE){
#
#
#   df <- group_by(ranking_clean, communities)
#
#   # Calculate Grouped Skyline
#   if(is_positive){
#   communityPareto <- psel(df, low(as.numeric(paper_date)) * high(metric))
#   globalPareto <- psel(ranking_clean, low(as.numeric(paper_date)) * high(metric))
#   }else{
#   communityPareto <- psel(df, low(as.numeric(paper_date)) * low(metric))
#   globalPareto <- psel(ranking_clean, low(as.numeric(paper_date)) * low(metric))
#   }
#
#   paretos <- list(communityPareto, globalPareto)
#
#   return(paretos)
#
# }
#
# count_occurrences <- function(papers){
#   affiliations <- as.list(strsplit(papers$communities_name,"@"))
#   affiliations <- unlist(affiliations)
#   affiliations <- as.data.frame(table(affiliations))
#   affiliations %>%
#     rename(
#         institution = affiliations,
#         counter = Freq
#     )
#
#
# }
#
# calculateFindings <- function(activity, globalPareto){
#
#   breakthrough <- count_occurrences(globalPareto)
#   all <- activity %>% left_join(breakthrough, by=c("institution"))
#   all <- all %>% rename(activity = counter.x, breakthrough = counter.y)
#   all[is.na(all$breakthrough),"breakthrough"] <- 0
#   all$effectiveness <- all$breakthrough/all$activity
#   return(all[order(-all$activity, -all$effectiveness),])
# }
#
#
#
# remove_duplicate <-function(df){
#   only_papers <- df
#  only_papers$title = sapply(strsplit(only_papers$title, "@@@"), head, 1)
#
#  only_papers <- only_papers[!duplicated(only_papers$title),]
#
#  return(only_papers)
# }
#
# all_findings <- data.frame(institution=character(),
#                            activity=integer(),
#                            breakthrough=integer(),
#                            effectiveness=double(),
#                            stringsAsFactors=FALSE)
# df = as.data.frame(all_papers[18])
#
#
# for(df in all_papers){ ##Find how to iterate
#   ranking_clean <- cleanData(df)
#   paretos <- calculatePareto(ranking_clean, TRUE)
#   ranking_clean <- remove_duplicate(ranking_clean)
#   globalPareto <-  remove_duplicate(paretos[[2]])
#   activity <- count_occurrences(remove_duplicate(ranking_clean))
#
#
#
#
#   breakthrough <- count_occurrences(globalPareto)
#   all <- activity %>% left_join(breakthrough, by=c("institution"))
#   all <- all %>% rename(activity = counter.x, breakthrough = counter.y)
#   all[is.na(all$breakthrough),"breakthrough"] <- 0
#   all$effectiveness <- all$breakthrough/all$activity
#
#
#
#
#   findings <- calculateFindings(activity,  remove_duplicate(paretos[[2]]))
#   all_findings <- rbind(all_findings, as.data.frame(findings))
# }
#
#
# aggregated <- bind_rows(all_findings) %>%
#           group_by(institution) %>%
#           summarise_each(funs(sum))
# aggregated$effectiveness <- aggregated$breakthrough/aggregated$activity
#
# aggregated <- as.data.frame(aggregated)
#
# aggregated <- aggregated[order(-aggregated$activity, -aggregated$effectiveness),]
# intitutions_appareances  <-  as.data.frame((table(all_findings$institution)))
# intitutions_appareances <- intitutions_appareances %>% rename(institutions = Var1,)
# intitutions_appareances <- intitutions_appareances[order(-intitutions_appareances$Freq),]
# intitutions_appareances
# aggregated
# Out:
#                                                          institution activity
# 11                                                            Google      227
# 2                                         Carnegie Mellon University      138
# 10                                                          Facebook      136
# 26                                               Stanford University      115
# 18                                                         Microsoft      114
# 95                                                 Peking University      103
# 63                                               Tsinghua University       72
# 5                                                 Cornell University       64
# 103                              The Chinese University of Hong Kong       59
# 39                                          University of Washington       58
# 64                                            Université de Montréal       54
# 152                                              Zhejiang University       46
# 73                     University of Science and Technology of China       46
# 108                               University of California, Berkeley       46
# 87                     Huazhong University of Science and Technology       46
# 99                                                         SenseTime       46
# 109                                          University of Cambridge       43
# 35                                              University of Oxford       39
# 150                                        Xi'an Jiaotong University       38
# 133                                               Beihang University       38
# 80                       Allen Institute for Artificial Intelligence       37
# 76                                              University of Sydney       36
# 107                                         University of California       33
# 88                                          Johns Hopkins University       32
# 105                                        University College London       32
# 84                                       Chinese Academy of Sciences       31
# 34                        University of Illinois at Urbana–Champaign       31
# 59                                           Northwestern University       29
# 302                                            University of Alberta       29
# 120                   Hong Kong University of Science and Technology       28
# 98                                                           Samsung       27
# 1                                                              Baidu       27
# 230                                University of Southern California       25
# 93                                  Nanyang Technological University       24
# 96                                                 Purdue University       24
# 132                               Amirkabir University of Technology       23
# 15                             Massachusetts Institute of Technology       23
# 119                                                 Fudan University       21
# 65                                            University of Adelaide       20
# 308                                              university of lille       19
# 86                                    Harbin Institute of Technology       19
# 163                                                              IBM       19
# 12                                                Harvard University       17
# 101                                                          Tencent       17
# 20                                               New York University       16
# 227                                          Jagiellonian University       16
# 97                                            RWTH Aachen University       16
# 156                        National University of Defense Technology       16
# 172                                                   Salesforce.com       16
# 213                                           Sun Yat-sen University       16
# 29                                           University of Amsterdam       15
# 66                                  University of California, Irvine       15
# 142                                    Shanghai Jiao Tong University       15
# 32                                           University of Edinburgh       15
# 149                                    University of Texas at Austin       15
# 24                                              Princeton University       15
# 137                                                           Huawei       15
# 118 French Institute for Research in Computer Science and Automation       14
# 191                                    Graz University of Technology       14
# 71                                            University of Michigan       14
# 81                                                        Amazon.com       14
# 7                                          École des ponts ParisTech       13
# 42                                                     Alibaba Group       13
# 208                                 Hong Kong Polytechnic University       13
# 111         University of Electronic Science and Technology of China       13
# 141                                      Russian Academy of Sciences       12
# 123                    Singapore University of Technology and Design       12
# 49                                                             Intel       12
# 25                                         Seoul National University       11
# 38                                             University of Toronto       11
# 67                                  University of California, Merced       11
# 94                                                            Nvidia       11
# 121                                               Rutgers University       11
# 127                                 University of Technology, Sydney       11
# 154                                   Australian National University       10
# 53                                                Nanjing University       10
# 237                                                  Duke University       10
# 83                                       Beijing Jiaotong University        9
# 139                                 Middle East Technical University        9
# 68                               University of California, San Diego        9
# 145                                                Tongji University        9
# 203                                                  York University        8
# 21                                                            OpenAI        8
# 110                                         University of Cincinnati        8
# 148                             University of Maryland, College Park        8
# 33                                            University of Freiburg        8
# 40                                                  Aalto University        8
# 164                                          Imperial College London        8
# 27                                    Technische Universität München        8
# 151                                                Xidian University        7
# 8                                           École Normale Supérieure        7
# 61                                   Sharif University of Technology        7
# 223                                          University of Rochester        7
# 286                                                     HEC Montréal        7
# 43                                Autonomous University of Barcelona        7
# 72                                          University of Notre Dame        7
# 78                                                 Yonsei University        7
# 136                                             Hacettepe University        7
# 147                                          University of Hong Kong        7
# 262                                University of Illinois at Chicago        7
# 272                                                McGill University        7
# 161                                  École Polytechnique de Montréal        6
# 16                                                Max Planck Society        6
# 41                                                     Adobe Systems        6
# 143                                           Stony Brook University        6
# 82                                   Beijing Institute of Technology        6
# 114                                           University of Waterloo        6
# 126                      University of North Carolina at Chapel Hill        6
# 102                                             Texas A&M University        5
# 146                                        University of East Anglia        5
# 234                         Nara Institute of Science and Technology        5
# 54                      Nanjing University of Science and Technology        5
# 188                                                       ETH Zurich        5
# 196                                  University of Wisconsin-Madison        5
# 229                       University of Massachusetts Medical School        5
# 293                                    University of New South Wales        5
# 3                                                Columbia University        5
# 30                                    University of British Columbia        5
# 124                            University of California, Los Angeles        5
# 219                          University of California, Santa Barbara        5
# 287                                   Information Sciences Institute        5
# 290                                 Technical University of Dortmund        5
# 189                                  Georgia Institute of Technology        4
# 194                                             Newcastle University        4
# 276                                               Queen's University        4
# 279                                             University of Ottawa        4
# 58                                                 Naver Corporation        4
# 115                                                  Yale University        4
# 235                                  Singapore Management University        4
# 50                                Johannes Kepler University of Linz        4
# 57                                  National University of Singapore        4
# 92                Nanjing University of Posts and Telecommunications        4
# 197                                               University of York        4
# 277                                   University of Colorado Boulder        4
# 284                                      Florida Atlantic University        4
# 294                                      Washington State University        4
# 209                                               Huaqiao University        3
# 300                                        University of Connecticut        3
# 135                                                 General Electric        3
# 169                                National Institute of Informatics        3
# 179                   Norwegian University of Science and Technology        3
# 211                                          Northeastern University        3
# 256                     German Center for Neurodegenerative Diseases        3
# 17                                         Michigan State University        3
# 62                         Toyota Technological Institute at Chicago        3
# 85      Commonwealth Scientific and Industrial Research Organisation        3
# 165                                          Jewish General Hospital        3
# 185                                         University of Nottingham        3
# 187                                     City University of Hong Kong        3
# 9                                                   Emory University        3
# 13                                    Katholieke Universiteit Leuven        3
# 52                                           Moscow State University        3
# 55                                                 Nankai University        3
# 56         National Research University – Higher School of Economics        3
# 69                                             University of Chicago        3
# 100                                                Temple University        3
# 122                                              Saarland University        3
# 130                                                Xiamen University        3
# 134            Electronics and Telecommunications Research Institute        3
# 176                                          University of Melbourne        3
# 177                                            Binghamton University        3
# 181                                              Shenzhen University        3
# 244        Penn State College of Information Sciences and Technology        3
# 252                                     Brigham and Women's Hospital        3
# 260                                          ShanghaiTech University        3
# 270                                              Griffith University        3
# 190                                  Georgia Tech Research Institute        2
# 238                        Institute for Infocomm Research Singapore        2
# 77                                             University of Warwick        2
# 158                         Canadian Institute for Advanced Research        2
# 167                           Lawrence Livermore National Laboratory        2
# 175                                             University of Bremen        2
# 217                                                          Twitter        2
# 224                                                 Wuhan University        2
# 249                           National University of Ireland, Galway        2
# 265                                                            Xerox        2
# 268                              University of Massachusetts Amherst        2
# 280                       Courant Institute of Mathematical Sciences        2
# 283                         École Polytechnique Fédérale de Lausanne        2
# 22                                                   Pace University        2
# 44                Beijing University of Posts and Telecommunications        2
# 47        Dalle Molle Institute for Artificial Intelligence Research        2
# 51                             Lawrence Berkeley National Laboratory        2
# 89                                                             KAIST        2
# 90                                             King's College London        2
# 91                                                  Korea University        2
# 104                                                          Toshiba        2
# 112                                             University of Geneva        2
# 116                             Academy of Military Medical Sciences        2
# 128                                              University of Tokyo        2
# 131                                                  Academia Sinica        2
# 144                                               Tianjin University        2
# 157                                                            Bosch        2
# 159                                                   D-Wave Systems        2
# 160                                     East China Normal University        2
# 166                                                 Kyoto University        2
# 178                                    National Tsing Hua University        2
# 186                                    Weizmann Institute of Science        2
# 192                                                 Jilin University        2
# 195                             South China University of Technology        2
# 207                               Guangdong University of Technology        2
# 210                                      Incheon National University        2
# 212                                               Sichuan University        2
# 216                                   Toyota Technological Institute        2
# 225                                              Carleton University        2
# 228                              Polytechnic University of Catalonia        2
# 231                                 University of the Basque Country        2
# 240                                                   Boston College        2
# 241                                               Oracle Corporation        2
# 242                                               Cardiff University        2
# 243                                              École Polytechnique        2
# 246                                 Federal University of Pernambuco        2
# 255                                                             eBay        2
# 259                                  Queen Mary University of London        2
# 303                                           University of Toulouse        2
# 304                                                           Xiaomi        2
# 14                                    Los Alamos National Laboratory        1
# 28                                           Trinity College, Dublin        1
# 155         Nanjing University of Information Science and Technology        1
# 183                              State University of New York System        1
# 198                                               Indiana University        1
# 202                                  University of Western Australia        1
# 247                                               Mahidol University        1
# 248                         Mahidol University International College        1
# 264                                              University of Turku        1
# 266                                                Tohoku University        1
# 267                                              University of Maine        1
# 273                                       National Taiwan University        1
# 299                                               University of Bari        1
# 301                                             University of Zurich        1
# 4                         Conservatoire national des arts et métiers        1
# 6                                                  Durham University        1
# 19                Nanjing University of Aeronautics and Astronautics        1
# 23                       Pohang University of Science and Technology        1
# 31                               University of California, Riverside        1
# 36                                               University of Paris        1
# 37                                  University of Texas at Arlington        1
# 45                                Costa Rica Institute of Technology        1
# 46                              Czech Technical University in Prague        1
# 48                              Federal University of Rio de Janeiro        1
# 60                                       Rovira i Virgili University        1
# 70                                                University of Jena        1
# 74                                     University of South Australia        1
# 75                                         University of Southampton        1
# 79                                              Ain Shams University        1
# 106                                             University of Alcalá        1
# 113                                             University of Warsaw        1
# 117                                    Chinese Ministry of Education        1
# 125                             University of Electro-Communications        1
# 129                              Xi'an Jiaotong-Liverpool University        1
# 138                                             Linköping University        1
# 140                                                         Qualcomm        1
# 153                                              University of Parma        1
# 162                                           Heriot-Watt University        1
# 168                   National and Kapodistrian University of Athens        1
# 170                                           Ritsumeikan University        1
# 171                                                  RMIT University        1
# 173                                              Tel Aviv University        1
# 174                                                Télécom ParisTech        1
# 180                                Rochester Institute of Technology        1
# 182                                             Southeast University        1
# 184                                           University of Missouri        1
# 193 National Institute of Advanced Industrial Science and Technology        1
# 199                        Mitsubishi Electric Research Laboratories        1
# 200                          National Technical University of Athens        1
# 201                                          University of Barcelona        1
# 204                                                  Ajou University        1
# 205                                    China Three Gorges University        1
# 206                                  Dalian University of Technology        1
# 214                        Technion – Israel Institute of Technology        1
# 215                                 Technische Universität Darmstadt        1
# 218                                               University of Bern        1
# 220                             University of California, Santa Cruz        1
# 221                                            University of Florida        1
# 222                    University of Ontario Institute of Technology        1
# 226                                         Idiap Research Institute        1
# 232               German Research Centre for Artificial Intelligence        1
# 233                       Moscow Institute of Physics and Technology        1
# 236                                          University of São Paulo        1
# 239                                       University of Pennsylvania        1
# 245                                             Tribhuvan University        1
# 250                                           University of Virginia        1
# 251                                        Beijing Normal University        1
# 253                                     Charles University in Prague        1
# 254                                           Dublin City University        1
# 257                                            Ohio State University        1
# 258                                          Pompeu Fabra University        1
# 261                                         University of Düsseldorf        1
# 263                                             University of Lisbon        1
# 269                                              Brandeis University        1
# 271                                       Instituto Superior Técnico        1
# 274                                          Oregon State University        1
# 275                                                          Philips        1
# 278                                           University of Helsinki        1
# 281                                                Deakin University        1
# 282                                              Shandong University        1
# 285                                               Hanyang University        1
# 288                                                Monash University        1
# 289                                    Pennsylvania State University        1
# 291                                         University of Birmingham        1
# 292                                    University of Central Florida        1
# 295                                  Istituto Italiano di Tecnologia        1
# 296                                Swiss Institute of Bioinformatics        1
# 297                                      Indian Institute of Science        1
# 298                        Indian Institute of Technology, Hyderabad        1
# 305                           Federal Institute of Rio Grande do Sul        1
# 306                                       Polish Academy of Sciences        1
# 307                                           University of Fribourg        1
#     breakthrough effectiveness
# 11            70    0.30837004
# 2             39    0.28260870
# 10            31    0.22794118
# 26            32    0.27826087
# 18            30    0.26315789
# 95            21    0.20388350
# 63            16    0.22222222
# 5             22    0.34375000
# 103           16    0.27118644
# 39            12    0.20689655
# 64            15    0.27777778
# 152           14    0.30434783
# 73            10    0.21739130
# 108           10    0.21739130
# 87             9    0.19565217
# 99             7    0.15217391
# 109            8    0.18604651
# 35            16    0.41025641
# 150           11    0.28947368
# 133            9    0.23684211
# 80             5    0.13513514
# 76            11    0.30555556
# 107           11    0.33333333
# 88            15    0.46875000
# 105           14    0.43750000
# 84             7    0.22580645
# 34             6    0.19354839
# 59            12    0.41379310
# 302            8    0.27586207
# 120            5    0.17857143
# 98             9    0.33333333
# 1              8    0.29629630
# 230            6    0.24000000
# 93            11    0.45833333
# 96             9    0.37500000
# 132            9    0.39130435
# 15             4    0.17391304
# 119            2    0.09523810
# 65             6    0.30000000
# 308            6    0.31578947
# 86             5    0.26315789
# 163            4    0.21052632
# 12             7    0.41176471
# 101            0    0.00000000
# 20             7    0.43750000
# 227            7    0.43750000
# 97             4    0.25000000
# 156            3    0.18750000
# 172            3    0.18750000
# 213            1    0.06250000
# 29             5    0.33333333
# 66             5    0.33333333
# 142            5    0.33333333
# 32             4    0.26666667
# 149            3    0.20000000
# 24             0    0.00000000
# 137            0    0.00000000
# 118            7    0.50000000
# 191            7    0.50000000
# 71             5    0.35714286
# 81             4    0.28571429
# 7              4    0.30769231
# 42             1    0.07692308
# 208            1    0.07692308
# 111            0    0.00000000
# 141            4    0.33333333
# 123            2    0.16666667
# 49             0    0.00000000
# 25             4    0.36363636
# 38             4    0.36363636
# 67             4    0.36363636
# 94             2    0.18181818
# 121            2    0.18181818
# 127            0    0.00000000
# 154            3    0.30000000
# 53             1    0.10000000
# 237            0    0.00000000
# 83             4    0.44444444
# 139            2    0.22222222
# 68             1    0.11111111
# 145            1    0.11111111
# 203            5    0.62500000
# 21             4    0.50000000
# 110            4    0.50000000
# 148            4    0.50000000
# 33             2    0.25000000
# 40             2    0.25000000
# 164            2    0.25000000
# 27             0    0.00000000
# 151            3    0.42857143
# 8              2    0.28571429
# 61             2    0.28571429
# 223            2    0.28571429
# 286            1    0.14285714
# 43             0    0.00000000
# 72             0    0.00000000
# 78             0    0.00000000
# 136            0    0.00000000
# 147            0    0.00000000
# 262            0    0.00000000
# 272            0    0.00000000
# 161            4    0.66666667
# 16             2    0.33333333
# 41             2    0.33333333
# 143            2    0.33333333
# 82             1    0.16666667
# 114            1    0.16666667
# 126            1    0.16666667
# 102            2    0.40000000
# 146            2    0.40000000
# 234            2    0.40000000
# 54             1    0.20000000
# 188            1    0.20000000
# 196            1    0.20000000
# 229            1    0.20000000
# 293            1    0.20000000
# 3              0    0.00000000
# 30             0    0.00000000
# 124            0    0.00000000
# 219            0    0.00000000
# 287            0    0.00000000
# 290            0    0.00000000
# 189            2    0.50000000
# 194            2    0.50000000
# 276            2    0.50000000
# 279            2    0.50000000
# 58             1    0.25000000
# 115            1    0.25000000
# 235            1    0.25000000
# 50             0    0.00000000
# 57             0    0.00000000
# 92             0    0.00000000
# 197            0    0.00000000
# 277            0    0.00000000
# 284            0    0.00000000
# 294            0    0.00000000
# 209            3    1.00000000
# 300            3    1.00000000
# 135            2    0.66666667
# 169            2    0.66666667
# 179            2    0.66666667
# 211            2    0.66666667
# 256            2    0.66666667
# 17             1    0.33333333
# 62             1    0.33333333
# 85             1    0.33333333
# 165            1    0.33333333
# 185            1    0.33333333
# 187            1    0.33333333
# 9              0    0.00000000
# 13             0    0.00000000
# 52             0    0.00000000
# 55             0    0.00000000
# 56             0    0.00000000
# 69             0    0.00000000
# 100            0    0.00000000
# 122            0    0.00000000
# 130            0    0.00000000
# 134            0    0.00000000
# 176            0    0.00000000
# 177            0    0.00000000
# 181            0    0.00000000
# 244            0    0.00000000
# 252            0    0.00000000
# 260            0    0.00000000
# 270            0    0.00000000
# 190            2    1.00000000
# 238            2    1.00000000
# 77             1    0.50000000
# 158            1    0.50000000
# 167            1    0.50000000
# 175            1    0.50000000
# 217            1    0.50000000
# 224            1    0.50000000
# 249            1    0.50000000
# 265            1    0.50000000
# 268            1    0.50000000
# 280            1    0.50000000
# 283            1    0.50000000
# 22             0    0.00000000
# 44             0    0.00000000
# 47             0    0.00000000
# 51             0    0.00000000
# 89             0    0.00000000
# 90             0    0.00000000
# 91             0    0.00000000
# 104            0    0.00000000
# 112            0    0.00000000
# 116            0    0.00000000
# 128            0    0.00000000
# 131            0    0.00000000
# 144            0    0.00000000
# 157            0    0.00000000
# 159            0    0.00000000
# 160            0    0.00000000
# 166            0    0.00000000
# 178            0    0.00000000
# 186            0    0.00000000
# 192            0    0.00000000
# 195            0    0.00000000
# 207            0    0.00000000
# 210            0    0.00000000
# 212            0    0.00000000
# 216            0    0.00000000
# 225            0    0.00000000
# 228            0    0.00000000
# 231            0    0.00000000
# 240            0    0.00000000
# 241            0    0.00000000
# 242            0    0.00000000
# 243            0    0.00000000
# 246            0    0.00000000
# 255            0    0.00000000
# 259            0    0.00000000
# 303            0    0.00000000
# 304            0    0.00000000
# 14             1    1.00000000
# 28             1    1.00000000
# 155            1    1.00000000
# 183            1    1.00000000
# 198            1    1.00000000
# 202            1    1.00000000
# 247            1    1.00000000
# 248            1    1.00000000
# 264            1    1.00000000
# 266            1    1.00000000
# 267            1    1.00000000
# 273            1    1.00000000
# 299            1    1.00000000
# 301            1    1.00000000
# 4              0    0.00000000
# 6              0    0.00000000
# 19             0    0.00000000
# 23             0    0.00000000
# 31             0    0.00000000
# 36             0    0.00000000
# 37             0    0.00000000
# 45             0    0.00000000
# 46             0    0.00000000
# 48             0    0.00000000
# 60             0    0.00000000
# 70             0    0.00000000
# 74             0    0.00000000
# 75             0    0.00000000
# 79             0    0.00000000
# 106            0    0.00000000
# 113            0    0.00000000
# 117            0    0.00000000
# 125            0    0.00000000
# 129            0    0.00000000
# 138            0    0.00000000
# 140            0    0.00000000
# 153            0    0.00000000
# 162            0    0.00000000
# 168            0    0.00000000
# 170            0    0.00000000
# 171            0    0.00000000
# 173            0    0.00000000
# 174            0    0.00000000
# 180            0    0.00000000
# 182            0    0.00000000
# 184            0    0.00000000
# 193            0    0.00000000
# 199            0    0.00000000
# 200            0    0.00000000
# 201            0    0.00000000
# 204            0    0.00000000
# 205            0    0.00000000
# 206            0    0.00000000
# 214            0    0.00000000
# 215            0    0.00000000
# 218            0    0.00000000
# 220            0    0.00000000
# 221            0    0.00000000
# 222            0    0.00000000
# 226            0    0.00000000
# 232            0    0.00000000
# 233            0    0.00000000
# 236            0    0.00000000
# 239            0    0.00000000
# 245            0    0.00000000
# 250            0    0.00000000
# 251            0    0.00000000
# 253            0    0.00000000
# 254            0    0.00000000
# 257            0    0.00000000
# 258            0    0.00000000
# 261            0    0.00000000
# 263            0    0.00000000
# 269            0    0.00000000
# 271            0    0.00000000
# 274            0    0.00000000
# 275            0    0.00000000
# 278            0    0.00000000
# 281            0    0.00000000
# 282            0    0.00000000
# 285            0    0.00000000
# 288            0    0.00000000
# 289            0    0.00000000
# 291            0    0.00000000
# 292            0    0.00000000
# 295            0    0.00000000
# 296            0    0.00000000
# 297            0    0.00000000
# 298            0    0.00000000
# 305            0    0.00000000
# 306            0    0.00000000
# 307            0    0.00000000
